# %%
import pandas as pd

# %%
# leer archivo Excel que contiene los topicos de Fundamentos de Analsis de Datos

dataDataSets = pd.read_csv('APIdata/datasets.csv')

# %%
dataDataSets.head()
# Out:
#    Unnamed: 0           topic       set  \
# 0           2  Data-scientist  datasets
# 1           4  Data-scientist  datasets
# 2           6  Data-scientist  datasets
# 3           8  Data-scientist  datasets
# 4          10  Data-scientist  datasets
#
#                                                  ref  \
# 0    nikhilbhathi/data-scientist-salary-us-glassdoor
# 1                      andrewmvd/data-scientist-jobs
# 2  arashnic/hr-analytics-job-change-of-data-scien...
# 3         sl6149/data-scientist-job-market-in-the-us
# 4                   omkargowda/data-scientist-salary
#
#                                          title    size          lastUpdated  \
# 0                        Data scientist salary  1023KB  2021-12-29 15:28:13
# 1                          Data Scientist Jobs     4MB  2020-07-16 04:04:58
# 2  HR Analytics: Job Change of Data Scientists   295KB  2020-12-07 00:25:10
# 3        Data Scientist Job Market in the U.S.    16MB  2018-08-31 17:34:49
# ...

# %%
dataDataSets.shape
# Out:
# (832, 10)

# %%
dataDataSets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 832 entries, 0 to 831
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       832 non-null    int64
#  1   topic            832 non-null    object
#  2   set              832 non-null    object
#  3   ref              832 non-null    object
#  4   title            832 non-null    object
#  5   size             832 non-null    object
#  6   lastUpdated      832 non-null    object
#  7   downloadCount    832 non-null    object
#  8   voteCount        832 non-null    object
#  9   usabilityRating  832 non-null    float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 65.1+ KB

# %%
# revisar nulos
dataDataSets.isnull().sum()
# Out:
# Unnamed: 0         0
# topic              0
# set                0
# ref                0
# title              0
# size               0
# lastUpdated        0
# downloadCount      0
# voteCount          0
# usabilityRating    0
# dtype: int64

# %%
# eliminar columnas

dataDataSets = dataDataSets.drop(['Unnamed: 0', 'topic'], axis=1)

# %%
# cambiar de nombre a las columnas

dataDataSets = dataDataSets.rename(columns={'set':'type', 'ref':'referencia', 'downloadCount':'downloads'})

# %%
dataDataSets.head()
# Out:
#        type                                         referencia  \
# 0  datasets    nikhilbhathi/data-scientist-salary-us-glassdoor
# 1  datasets                      andrewmvd/data-scientist-jobs
# 2  datasets  arashnic/hr-analytics-job-change-of-data-scien...
# 3  datasets         sl6149/data-scientist-job-market-in-the-us
# 4  datasets                   omkargowda/data-scientist-salary
#
#                                          title    size          lastUpdated  \
# 0                        Data scientist salary  1023KB  2021-12-29 15:28:13
# 1                          Data Scientist Jobs     4MB  2020-07-16 04:04:58
# 2  HR Analytics: Job Change of Data Scientists   295KB  2020-12-07 00:25:10
# 3        Data Scientist Job Market in the U.S.    16MB  2018-08-31 17:34:49
# 4                        Data Scientist Salary    88KB  2022-07-09 11:25:59
#
#   downloads voteCount  usabilityRating
# 0     10588       174         1.000000
# 1      3212        92         1.000000
# ...

# %%
#for x in dataDataSets:
    #getAutor = x['referencia'].split('/')

# %% [markdown]
# # Notebooks

# %%
# leer archivo Excel que contiene los topicos de Fundamentos de Analsis de Datos

dataNoteboks = pd.read_csv('APIdata/notebooks.csv')

# %%
dataNoteboks.head()
# Out:
#    Unnamed: 0 topic      set  \
# 0           2   NaN  kernels
# 1           4   NaN  kernels
# 2           6   NaN  kernels
# 3           8   NaN  kernels
# 4          10   NaN  kernels
#
#                                                  ref  \
# 0    anokas/data-analysis-xgboost-starter-0-35460-lb
# 1                  dimarudov/data-analysis-using-sql
# 2             peterchang77/exploratory-data-analysis
# 3  kashnitsky/topic-1-exploratory-data-analysis-w...
# 4                   anokas/data-exploration-analysis
#
#                                             title           author  \
# 0    Data Analysis & XGBoost Starter (0.35460 LB)           anokas
# 1                         Data Analysis using SQL       Dima Rudov
# 2                       Exploratory Data Analysis            Peter
# 3  Topic 1. Exploratory Data Analysis with Pandas  Yury Kashnitsky
# 4                     Data Exploration & Analysis           anokas
#
#            lastRunTime totalVotes
# ...

# %%
dataNoteboks.shape
# Out:
# (497, 8)

# %%
dataNoteboks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   497 non-null    int64
#  1   topic        177 non-null    object
#  2   set          497 non-null    object
#  3   ref          491 non-null    object
#  4   title        497 non-null    object
#  5   author       491 non-null    object
#  6   lastRunTime  497 non-null    object
#  7   totalVotes   497 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 31.2+ KB

# %%
dataNoteboks.isnull().sum()
# Out:
# Unnamed: 0       0
# topic          320
# set              0
# ref              6
# title            0
# author           6
# lastRunTime      0
# totalVotes       0
# dtype: int64

# %%
# eliminar columnas innecesarias

dataNoteboks = dataNoteboks.drop(['Unnamed: 0', 'topic'], axis=1)

# %%
# cambiar de nombre a las columnas

dataNoteboks = dataNoteboks.rename(columns={'set':'type', 'ref':'referencia'})

# %%
dataNoteboks.head(50)
# Out:
#        type                                         referencia  \
# 0   kernels    anokas/data-analysis-xgboost-starter-0-35460-lb
# 1   kernels                  dimarudov/data-analysis-using-sql
# 2   kernels             peterchang77/exploratory-data-analysis
# 3   kernels  kashnitsky/topic-1-exploratory-data-analysis-w...
# 4   kernels                   anokas/data-exploration-analysis
# 5   kernels                 anokas/exploratory-data-analysis-4
# 6   kernels                      rounakbanik/ted-data-analysis
# 7   kernels  ekami66/detailed-exploratory-data-analysis-wit...
# 8   kernels                         ruslankl/eeg-data-analysis
# 9   kernels            ihelon/hubmap-exploratory-data-analysis
# 10  kernels             mmetter/pokemon-data-analysis-tutorial
# 11  kernels                   jonathanbouchet/f1-data-analysis
# 12  kernels  pmarcelino/data-analysis-and-feature-extractio...
# 13  kernels           loaiabdalslam/sales-data-analysis-report
# ...

# %%
dataNoteboks.shape
# Out:
# (497, 6)
