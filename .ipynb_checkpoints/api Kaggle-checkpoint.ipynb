# %% [markdown]
# # Api Kaggle

# %%
import kaggle
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import itertools
from PIL import Image
from IPython.core import display as ICD
# %matplotlib inline

# %%
# importar libreria kaggle
from kaggle.api.kaggle_api_extended import KaggleApi

# %%
# llamar a la api key de kaggle

api = KaggleApi()
api.authenticate()

# %%
def convert_to_df(csv): # needs to be repaired
    df = pd.DataFrame(data=csv)[0].str.split(',',expand=True)  
    header = df.iloc[0]
    df = df[1:]
    df.columns = header
    return df

# %%
temas = ['regression']

# %%
# extraer competitions

competitions_list_csv = !kaggle competitions list --csv

competitions_list_df = convert_to_df(competitions_list_csv)
print('20 Competitions from Kaggle.com/competitions:')
ICD.display(competitions_list_df.head(10))
# Out:
# 20 Competitions from Kaggle.com/competitions:
# 0                                   ref             deadline         category  \
# 1                                                       None             None
# 2          contradictory-my-dear-watson  2030-07-01 23:59:00  Getting Started
# 3                                                       None             None
# 4                   gan-getting-started  2030-07-01 23:59:00  Getting Started
# 5                                                       None             None
# 6   store-sales-time-series-forecasting  2030-06-30 23:59:00  Getting Started
# 7                                                       None             None
# 8                   tpu-getting-started  2030-06-03 23:59:00  Getting Started
# 9                                                       None             None
# 10                     digit-recognizer  2030-01-01 00:00:00  Getting Started
#
# 0      reward teamCount userHasEntered   NaN
# 1        None      None           None  None
# 2      Prizes        42          False  None
# 3        None      None           None  None
# 4      Prizes        52          False  None
# 5        None      None           None  None
# 6   Knowledge       591          False  None
# 7        None      None           None  None
# 8   Knowledge        93          False  None
# 9        None      None           None  None
# 10  Knowledge      1213          False  None

# %%
# extraer datasets

datasets_list_csv = !kaggle datasets list --csv

datasets_list_df = convert_to_df(datasets_list_csv)

datasets_list_df_sorted = datasets_list_df.sort_values(by='lastUpdated', ascending=0)
ICD.display(datasets_list_df_sorted.head())
# Out:
# 0                                              ref  \
# 40                    nolanbconaway/pitchfork-data
# 18       iamsouravbanerjee/nifty500-stocks-dataset
# 8                 ramjasmaurya/1-gb-internet-price
# 20  gabrielsantello/cars-purchase-decision-dataset
# 16        mukuldeshantri/ecommerce-fashion-dataset
#
# 0                                            title                    size  \
# 40                                             "18  393 Pitchfork Reviews"
# 18                Stock Market Dataset (NIFTY-500)                    35KB
# 8   Internet Prices around 200+ countries in 2022.                    22KB
# 20                Cars - Purchase Decision Dataset                     6KB
# 16            E-commerce Dataset with 30K Products                   546KB
#
# 0           lastUpdated        downloadCount voteCount usabilityRating  \
# 40                 33MB  2017-01-13 04:18:10     10608             371
# 18  2022-07-17 11:46:10                  982        67             1.0
# 8   2022-07-17 02:56:12                 1677        53       0.9705882
# 20  2022-07-09 13:18:38                  858        30             1.0
# 16  2022-07-08 12:28:18                 1133        41             1.0
#
# 0         NaN
# 40  0.7058824
# 18       None
# 8        None
# 20       None
# 16       None

# %%
# no me saca suficiente info

datasets = kaggle.api.dataset_list(search="regression")
print(datasets)
# Out:
# [andonians/random-linear-regression, abrambeyer/openintro-possum, dragonheir/logistic-regression, nkitgupta/jigsaw-regression-based-data, tanuprabhu/linear-regression-dataset, mirichoi0218/insurance, maajdl/yeh-concret-data, hellbuoy/car-price-prediction, fedesoriano/the-boston-houseprice-data, harlfoxem/housesalesprediction, dileep070/heart-disease-prediction-using-logistic-regression, heptapod/titanic, uciml/red-wine-quality-cortez-et-al-2009, quantbruce/real-estate-price-prediction, kandij/diabetes-dataset, azeembootwala/titanic, ishadss/productivity-prediction-of-garment-employees, rhuebner/human-resources-data-set, uciml/electric-power-consumption-data-set, karthickveerakumar/salary-data-simple-linear-regression]

# %%
csvregression = !kaggle datasets list -s regression --csv

csvregression

csvregression = convert_to_df(csvregression)

#csvregression = csvregression.sort_values(by='lastUpdated', ascending=0)
ICD.display(csvregression.head(30))

#csvregression.shape
# Out:
# 0                                                 ref  \
# 1
# 2                  andonians/random-linear-regression
# 3
# 4                         abrambeyer/openintro-possum
# 5
# 6                      dragonheir/logistic-regression
# 7
# 8              nkitgupta/jigsaw-regression-based-data
# 9
# 10               tanuprabhu/linear-regression-dataset
# 11
# 12                             mirichoi0218/insurance
# 13
# 14                            maajdl/yeh-concret-data
# 15
# 16                      hellbuoy/car-price-prediction
# 17
# 18             fedesoriano/the-boston-houseprice-data
# 19
# 20                     harlfoxem/housesalesprediction
# 21
# 22  dileep070/heart-disease-prediction-using-logis...
# 23
# 24                                   heptapod/titanic
# 25
# 26           uciml/red-wine-quality-cortez-et-al-2009
# 27
# 28            quantbruce/real-estate-price-prediction
# 29
# 30                            kandij/diabetes-dataset
#
# 0                                               title   size  \
# 1                                                None   None
# 2                                   Linear Regression    8KB
# 3                                                None   None
# 4                                   Possum Regression    2KB
# 5                                                None   None
# 6                                 Logistic Regression    3KB
# 7                                                None   None
# 8                        Jigsaw Regression Based Data    3GB
# 9                                                None   None
# 10                         Linear Regression Data-set    1KB
# 11                                               None   None
# 12                     Medical Cost Personal Datasets   16KB
# 13                                               None   None
# 14         Revisiting  a Concrete Strength regression   10KB
# 15                                               None   None
# 16    Car Price Prediction Multiple Linear Regression   18KB
# 17                                               None   None
# 18  Boston House Prices-Advanced Regression Techni...   12KB
# 19                                               None   None
# 20                        "House Sales in King County   USA"
# 21                                               None   None
# 22       Logistic regression To predict heart disease   58KB
# 23                                               None   None
# 24                                            Titanic   11KB
# 25                                               None   None
# 26                                   Red Wine Quality   26KB
# 27                                               None   None
# 28                       Real estate price prediction    7KB
# 29                                               None   None
# 30     Diabetics prediction using logistic regression    9KB
#
# 0           lastUpdated        downloadCount voteCount usabilityRating  \
# 1                  None                 None      None            None
# 2   2017-05-11 20:15:52                42001       435       0.8235294
# 3                  None                 None      None            None
# 4   2021-08-17 01:15:54                 2713        38             1.0
# 5                  None                 None      None            None
# 6   2017-12-24 08:11:43                19179       151       0.4117647
# 7                  None                 None      None            None
# 8   2022-02-05 20:51:56                 1234       103      0.88235295
# 9                  None                 None      None            None
# 10  2019-06-21 05:57:12                 6297        60             1.0
# 11                 None                 None      None            None
# 12  2018-02-21 00:15:14               145525      1953      0.88235295
# 13                 None                 None      None            None
# 14  2018-06-15 20:26:01                 5258       104      0.88235295
# 15                 None                 None      None            None
# 16  2019-10-15 16:45:27                34107       379       0.7058824
# 17                 None                 None      None            None
# 18  2021-06-01 10:39:10                 5558       107             1.0
# 19                 None                 None      None            None
# 20                780KB  2016-08-25 15:52:49    145147            1872
# 21                 None                 None      None            None
# 22  2019-06-07 06:12:56                24723       296       0.7058824
# 23                 None                 None      None            None
# 24  2017-05-16 08:14:22                45249       855       0.7058824
# 25                 None                 None      None            None
# 26  2017-11-27 23:41:08               149746      2202      0.88235295
# 27                 None                 None      None            None
# 28  2018-12-08 09:13:48                37681       331      0.47058824
# 29                 None                 None      None            None
# 30  2019-05-07 05:18:45                13561       153       0.5294118
#
# 0         NaN
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20  0.7058824
# 21       None
# 22       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
# 30       None

# %%
csvregression.dropna()
# Out:
# 0                                                 ref  \
# 2                  andonians/random-linear-regression
# 4                tanuprabhu/linear-regression-dataset
# 6                              mirichoi0218/insurance
# 8                       hellbuoy/car-price-prediction
# 10  karthickveerakumar/salary-data-simple-linear-r...
# 12         kolawale/focusing-on-mobile-app-or-website
# 14            quantbruce/real-estate-price-prediction
# 16     karthickveerakumar/startup-logistic-regression
# 18                   tmcketterick/heights-and-weights
# 20  erolmasimov/price-prediction-multiple-linear-r...
# 22                 dev0914sharma/car-purchasing-model
# 24  mayurdalvi/simple-linear-regression-placement-...
# 26           nehalbirla/vehicle-dataset-from-cardekho
# 28                              dmvreddy91/usahousing
# 30                             aungpyaeap/fish-market
# 32                       testpython/linear-regression
# 34                himanshunakrani/student-study-hours
# 36                                kashnitsky/mlcourse
# 38  shubham47/students-score-dataset-linear-regres...
# 40                    arejet/simple-linear-regression
#
# 0                                             title   size  \
# 2                                 Linear Regression    8KB
# 4                        Linear Regression Data-set    1KB
# 6                    Medical Cost Personal Datasets   16KB
# 8   Car Price Prediction Multiple Linear Regression   18KB
# 10           Salary data - Simple linear regression   378B
# 12            Linear Regression  E-commerce Dataset   43KB
# 14                     Real estate price prediction    7KB
# 16             Startup - Multiple Linear Regression    1KB
# 18                              Heights and weights   262B
# 20     Price Prediction -Multiple Linear Regression    6KB
# 22                             Car Purchasing Model   24KB
# 24        Simple Linear Regression - Placement data    4KB
# 26                                  Vehicle dataset  227KB
# 28                                Linear regression  363KB
# 30                                      Fish market    2KB
# 32                                Linear regression    8KB
# 34                              Student Study Hours   276B
# 36                                      mlcourse.ai   51MB
# 38       Students Score Dataset - Linear Regression   303B
# 40                         Simple Linear Regression  780KB
#
# 0           lastUpdated downloadCount voteCount usabilityRating
# 2   2017-05-11 20:15:52         42001       435       0.8235294
# 4   2019-06-21 05:57:12          6297        60             1.0
# 6   2018-02-21 00:15:14        145525      1953      0.88235295
# 8   2019-10-15 16:45:27         34107       379       0.7058824
# 10  2018-01-22 17:09:38         34787       222       0.3529412
# 12  2019-09-16 19:04:27          5237        50           0.625
# 14  2018-12-08 09:13:48         37680       331      0.47058824
# 16  2018-01-29 11:42:03          5854        48      0.47058824
# 18  2018-01-06 21:42:20          6470        67       0.7058824
# 20  2022-08-03 20:54:12           536        25       0.7647059
# 22  2021-04-30 15:59:08          1958        32       0.8235294
# 24  2021-11-15 15:02:18          1100        21             1.0
# 26  2020-10-24 01:29:16         78593       668             1.0
# 28  2017-10-10 18:34:48          2199        15      0.29411766
# 30  2019-06-13 10:20:33         41068       408             1.0
# 32  2018-03-18 12:51:45          1287        12      0.29411766
# 34  2022-07-20 13:17:29          5885       145             1.0
# 36  2018-12-09 16:45:09         34085      1502      0.88235295
# 38  2021-02-20 19:25:46          1113        15       0.5882353
# 40  2018-01-17 19:38:13          1311        25      0.29411766

# %%
def obtenerDatasets(temas):
    csvregression = !kaggle datasets list -s temas --csv

    csvregression
    
    csvregression = convert_to_df(csvregression)
    
    #csvregression = csvregression.sort_values(by='lastUpdated', ascending=0)
    #ICD.display(csvregression.head(30))
    
    #csvregression.shape
    return(csvregression)

# %%
datasets = obtenerDatasets(temas)
datasets
# Out:
# 0                                                 ref  \
# 1
# 2                                 upadorprofzs/testes
# 3
# 4                  gilbertlurduy/thewildproject-clips
# 5
# 6   gabrielpistelli/notas-taquigrficas-da-cpi-da-c...
# 7
# 8   hinepo/pesquisa-nacional-por-amostra-de-domicl...
# 9
# 10                      datacertlaboratoria/projeto-6
# 11
# 12                        emmanuelleai/enarm-20012019
# 13
# 14  camposfe1/clasifiacin-de-enfermedades-del-agua...
# 15
# 16               leandrobage/exerciciosistemasdecisao
# 17
#
# 0                                               title   size  \
# 1                                                None   None
# 2   Pesquisa Nacional por Amostra de Domicílios - ...  749KB
# 3                                                None   None
# 4                                TheWildProject_Clips  569KB
# 5                                                None   None
# 6              Notas Taquigráficas da CPI da Pandemia    6MB
# 7                                                None   None
# 8   Pesquisa Nacional por Amostra de Domicílios (P...  459KB
# 9                                                None   None
# 10                                Projeto 6: Capstone    1KB
# 11                                               None   None
# 12                    ENARM DEL 2001 AL 2019 - México   34KB
# 13                                               None   None
# 14       Clasificación de enfermedades del aguacatero  155MB
# 15                                               None   None
# 16                           exerciciosistemasdecisao    4KB
# 17                                               None   None
#
# 0           lastUpdated downloadCount voteCount usabilityRating
# 1                  None          None      None            None
# 2   2020-05-09 18:34:26           408        69       0.5882353
# 3                  None          None      None            None
# 4   2022-05-08 14:28:30            13         7       0.9117647
# 5                  None          None      None            None
# 6   2022-01-10 23:34:46             8         1       0.9117647
# 7                  None          None      None            None
# 8   2021-09-07 03:05:50            80         6       0.5294118
# 9                  None          None      None            None
# 10  2022-07-13 20:49:59            36         5             1.0
# 11                 None          None      None            None
# 12  2020-12-16 20:20:50           129         6             1.0
# 13                 None          None      None            None
# 14  2022-06-21 18:38:35            49         2       0.8235294
# 15                 None          None      None            None
# 16  2021-04-27 06:06:51             3         0       0.1764706
# 17                 None          None      None            None

# %%
csvregression['type'] = 'dataframe'
csvregression.head()
# Out:
# 0                                                 ref  \
# 18                     harlfoxem/housesalesprediction
# 8              nkitgupta/jigsaw-regression-based-data
# 4                         abrambeyer/openintro-possum
# 20             fedesoriano/the-boston-houseprice-data
# 34  ishadss/productivity-prediction-of-garment-emp...
#
# 0                                               title   size  \
# 18                        "House Sales in King County   USA"
# 8                        Jigsaw Regression Based Data    3GB
# 4                                   Possum Regression    2KB
# 20  Boston House Prices-Advanced Regression Techni...   12KB
# 34      Productivity Prediction of Garment Employees    16KB
#
# 0           lastUpdated        downloadCount voteCount usabilityRating  \
# 18                780KB  2016-08-25 15:52:49    138183            1840
# 8   2022-02-05 20:51:56                 1181       103      0.88235295
# 4   2021-08-17 01:15:54                 2124        34             1.0
# 20  2021-06-01 10:39:10                 4663        93             1.0
# 34  2021-04-06 22:42:06                 3223        62       0.9705882
#
# 0         NaN       type
# 18  0.7058824  dataframe
# 8        None  dataframe
# 4        None  dataframe
# 20       None  dataframe
# 34       None  dataframe

# %%
# extraer notebooks

kernel = !kaggle kernels list -s prediction

kernel = convert_to_df(kernel)


ICD.display(kernel.head())
# Out:
# 0 ref                                                             title                                              author                    lastRunTime          totalVotes
# 1  ----------------------------------------------...
# 2  ash316/eda-to-prediction-dietanic             ...
# 3  therealcyberlord/coronavirus-covid-19-visualiz...
# 4  gpreda/santander-eda-and-prediction           ...
# 5  buddhiniw/breast-cancer-prediction            ...

# %%
# graphql khan academy
