# %%
import pandas as pd
import numpy as np
import json
import pprint

# %%
# leer csv de metadatos de youtube

dataYoutube = pd.read_csv('../dataExtraction/api_dataExtraction/videosYoutube.csv')

# %%
dataYoutube.head()
# Out:
#    Unnamed: 0           kind                         etag           id  \
# 0           0  youtube#video  i0ByCrO1biymsZel0wr2P70sqpw  DXSgLLL3t58
# 1           1  youtube#video  4__RwgpcuORnhVJ4cHHAiZTGyiQ  fYpxOo5hRdA
# 2           2  youtube#video  UGBy7cMg1JUZw7IsfHCuKUH7yeo  SYiI-oB1FTs
# 3           3  youtube#video  WK8zwC3ty2sWbB05-fw-BMTyV-M  RMHYb9Bs6dg
# 4           4  youtube#video  bSoA0b7_jmEoMr-krPNbg3NecQs  xlYC-_FUUS8
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2022-11-17T15:36:51Z  UCSidMlxGqZ0NBrTjGzhfdjg
# 1  2022-11-17T15:36:52Z  UCSidMlxGqZ0NBrTjGzhfdjg
# 2  2022-11-17T15:36:55Z  UCSidMlxGqZ0NBrTjGzhfdjg
# 3  2022-11-17T15:36:57Z  UCSidMlxGqZ0NBrTjGzhfdjg
# 4  2022-07-25T22:00:26Z  UCSidMlxGqZ0NBrTjGzhfdjg
#
#                              snippet.title  \
# 0      ISLP 2022/23 - Como hacer un póster
# 1        ISLP 2022/23 - Estadística básica
# 2           ISLP 2022/23 - Visualizaciones
# 3  ISLP 2022/23 - Fuentes de datos del MAE
# ...

# %%
dataYoutube.shape
# Out:
# (38, 36)

# %%
dataYoutube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 36 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          38 non-null     int64
#  1   kind                                38 non-null     object
#  2   etag                                38 non-null     object
#  3   id                                  38 non-null     object
#  4   snippet.publishedAt                 38 non-null     object
#  5   snippet.channelId                   38 non-null     object
#  6   snippet.title                       38 non-null     object
#  7   snippet.description                 38 non-null     object
#  8   snippet.thumbnails.default.url      38 non-null     object
#  9   snippet.thumbnails.default.width    38 non-null     int64
#  10  snippet.thumbnails.default.height   38 non-null     int64
# ...

# %%
print(dataYoutube['snippet.thumbnails.maxres.url'])
# Out:
# 0     https://i.ytimg.com/vi/DXSgLLL3t58/maxresdefau...
# 1     https://i.ytimg.com/vi/fYpxOo5hRdA/maxresdefau...
# 2     https://i.ytimg.com/vi/SYiI-oB1FTs/maxresdefau...
# 3     https://i.ytimg.com/vi/RMHYb9Bs6dg/maxresdefau...
# 4     https://i.ytimg.com/vi/xlYC-_FUUS8/maxresdefau...
# 5     https://i.ytimg.com/vi/bXfLr_I2Unw/maxresdefau...
# 6     https://i.ytimg.com/vi/Q9pAqCL64dc/maxresdefau...
# 7     https://i.ytimg.com/vi/RAG5PI5Ra3c/maxresdefau...
# 8     https://i.ytimg.com/vi/4O-s6mv4-ug/maxresdefau...
# 9     https://i.ytimg.com/vi/Uj_tJoeeubU/maxresdefau...
# 10    https://i.ytimg.com/vi/lft37iZPbts/maxresdefau...
# 11    https://i.ytimg.com/vi/OeqKuSXa5jU/maxresdefau...
# 12    https://i.ytimg.com/vi/AUK47W_fg4E/maxresdefau...
# 13    https://i.ytimg.com/vi/JGXSs_Xyz_0/maxresdefau...
# 14    https://i.ytimg.com/vi/SKNAiBtJ5tU/maxresdefau...
# 15    https://i.ytimg.com/vi/l0d2TW1WUtM/maxresdefau...
# 16    https://i.ytimg.com/vi/Vify7t3Tt44/maxresdefau...
# ...

# %%
# revisar nulos
dataDataSets.isnull().sum()
# Out:
# Unnamed: 0                             0
# kind                                   0
# etag                                   0
# id                                     0
# snippet.publishedAt                    0
# snippet.channelId                      0
# snippet.title                          0
# snippet.description                    0
# snippet.thumbnails.default.url         0
# snippet.thumbnails.default.width       0
# snippet.thumbnails.default.height      0
# snippet.thumbnails.medium.url          0
# snippet.thumbnails.medium.width        0
# snippet.thumbnails.medium.height       0
# snippet.thumbnails.high.url            0
# snippet.thumbnails.high.width          0
# snippet.thumbnails.high.height         0
# snippet.thumbnails.standard.url        1
# snippet.thumbnails.standard.width      1
# snippet.thumbnails.standard.height     1
# snippet.thumbnails.maxres.url          1
# snippet.thumbnails.maxres.width        1
# snippet.thumbnails.maxres.height       1
# ...

# %%
# eliminar columnas

dataDataSets = dataDataSets.drop(['Unnamed: 0', ], axis=1)
